# %%
import pandas as pd
import re # Модуль re предназначен для поиска шаблонов в тексте и встроен в язык, поэтому не нуждается в установке.

# def get_year_release(arg):
#     # Данная функция основана на регулярных выражениях и использует модуль re, с которым мы пока не работали. 
#     #находим все слова по шаблону "(DDDD)"
#     candidates = re.findall(r'\(\d{4}\)', arg) 
#     # проверяем число вхождений
#     if len(candidates) > 0:
#         #если число вхождений больше 0,
# 	#очищаем строку от знаков "(" и ")"
#         year = candidates[0].replace('(', '')
#         year = year.replace(')', '')
#         return int(year)
#     else:
#         #если год не указан, возвращаем None
#         return None

# ratings_movies = pd.read_csv('D:/python/GUESS/РАБОЧАЯ/PANDAS/DATA/ratings_movies.csv', sep = ',')

# joined = ratings_movies.copy()
# # Задание 8.1 Создайте в таблице новый признак year_release, который соответствует году выпуска фильма.
# # У скольких фильмов не указан год их выпуска?

# # Из модуля re нам понадобится только функция findall(), которая позволяет найти в строке все слова, удовлетворяющие шаблону.
# # Мы находим в строке с названием фильма шаблон "(DDDD)" — четыре цифры, обёрнутых в скобки, что соответствует году 
# # выпуска фильма. Если такого шаблона не было найдено (год выпуска не указан), функция возвращает None
# # (в таблице это будет помечено как пропуск).

# joined['year_release'] = joined['title'].apply(get_year_release)
# # print(joined.shape[0] - joined['year_release'].count() )
# # print(joined.head())

# # Задание 8.2 Какой фильм, выпущенный в 1999 году, получил наименьшую среднюю оценку зрителей?
# # В качестве ответа запишите название этого фильма без указания года его выпуска.
# mask = joined['year_release'] == 1999
# joined[mask].groupby('title')['rating'].mean().sort_values()

# # Задание 8.3 Какое сочетание жанров фильмов (genres), выпущенных в 2010 году, получило наименьшую среднюю оценку (rating)?
# # Запишите сочетание так же, как оно указано в таблице (через разделитель |, без пробелов).

# mask2 = joined['year_release'] == 2010
# joined[mask2].groupby('genres')['rating'].mean().sort_values(ascending= False )


# # Задание 8.4 Какой пользователь (userId) посмотрел наибольшее количество различных (уникальных) комбинаций жанров (genres) фильмов?
# # В качестве ответа запишите идентификатор этого пользователя.

# joined.groupby('userId')['genres'].nunique().sort_values(ascending= False)

# # Задание 8.5 : 1 Найдите пользователя, который выставил наименьшее количество оценок, но его средняя оценка фильмам наибольшая.
# # В качестве ответа укажите идентификатор этого пользователя.
# # Чтобы рассчитать несколько параметров для каждого пользователя (количество оценок и среднюю оценку), можно воспользоваться 
# # методом agg() на сгруппированных данных.

# joined.groupby('userId')['rating'].agg(
#     ['count', 'mean']
#     ).sort_values(by=['count', 'mean'], ascending= [True, False])



# # Задание 8.6 Найдите сочетание жанров (genres) за 2018 год, которое имеет наибольший средний рейтинг 
# # (среднее по столбцу rating), и при этом число выставленных ему оценок (количество значений в столбце rating) больше 10.
# # Запишите сочетание так же, как оно указано в таблице (через разделитель |, без пробелов).
# mask = joined['year_release'] == 2018
# grouped = joined[mask].groupby('genres')['rating'].agg(
#     ['mean', 'count']
# )
# # print(grouped)

# grouped[grouped['count']>10].sort_values(
#     by='mean',
#     ascending=False
# )


# # Задание 8.7 Добавьте в таблицу новый признак year_rating — год выставления оценки. Создайте сводную таблицу, 
# # которая иллюстрирует зависимость среднего рейтинга фильма от года выставления оценки и жанра. Выберите верные 
# # варианты ответа, исходя из построенной таблицы:
# joined['date'] = pd.to_datetime(joined['date'])
# joined['year_rating'] = joined['date'].dt.year
# mask_1 = joined['genres'] == 'Action|Adventure'

# #A       За весь период (с 1996 по 2018 год) сочетание жанров Action|Adventure ни разу не получало среднюю оценку ниже 3.
# print(joined[mask_1].groupby(['year_rating','genres'])['rating'].mean().min()>3)

# #B       Наилучшую оценку жанр Action|Adventure|Animation|Children|Comedy|IMAX получил в 2010 году.
# mask_2 = joined['genres'] == 'Action|Adventure|Animation|Children|Comedy|IMAX'
# joined[mask_2].groupby('year_rating')['rating'].max().sort_values(ascending= False)

# #C       Среди сочетаний жанров, получивших наивысшую среднюю оценку в 2018 году, есть сочетание Animation|Children|Mystery.
# mask_2018 = joined['year_rating'] == 2018
# print(joined[mask_2018].groupby('genres')['rating'].mean()['Animation|Children|Mystery'] == 5)

# #D       Для жанра Comedy прослеживается тенденция падения рейтинга с каждым годом (с 1996 по 2018). 
# mask_comedy = joined['genres'] == 'Comedy'
# joined[mask_comedy].groupby('year_rating')['rating'].mean() 






# Дано два файла:


#orders.csv, содержащий данные о заказах;
#products.csv, содержащий данные о товарах.

orders = pd.read_csv('D:/python/GUESS/РАБОЧАЯ/PANDAS/DATA/orders_and_products/orders.csv', sep = ';')
products = pd.read_csv('D:/python/GUESS/РАБОЧАЯ/PANDAS/DATA/orders_and_products/products.csv', sep = ';')

orders_x = orders.copy()
products_x= products.copy()

orders_x['Product_ID'] = orders_x['ID товара']
orders_x.drop(['ID товара'], axis=1)

# Задание 8.8 Какой идентификатор (Order ID) имеет заказ, для которого не оказалось информации о товаре?
orders_products = orders_x.merge(
    products_x,
    on = 'Product_ID',
    how = 'left'   
)
orders_products

  # Задание 8.9 На какой товар была произведена отмена? В качестве ответа запишите название этого товара (Name).  
# mask_z = orders_products['Статус'] == 'Отменён'
# orders_products[mask_z]

# Задание 8.10 Какой покупатель принёс наибольшую суммарную прибыль интернет-магазину за указанный период?
# В ответ запишите идентификатор этого покупателя (ID Покупателя).
# Прибыль состоит только из оплаченных заказов и рассчитывается как количество купленного товара, умноженное на его цену.
def oplata(money):
  temp_str = money.split(',')
  list_x = ['Оплачен', 'Выполнен']
  if temp_str[0] in list_x:
    return 1
  return 0
orders_products['yes'] = orders_products['Статус'].apply(oplata) 
mask_opl = orders_products['yes'] == 1
orders_products['finally'] = orders_products[mask_opl]['Количество'] * orders_products[mask_opl]['Price']  
orders_products.groupby('ID Покупателя')['finally'].sum().sort_values(ascending= False)

#                 или проще:
orders_products['Profit'] = orders_products['Price'] * orders_products['Количество'] 
orders_products[orders_products['Оплачен'] == 'Да'].groupby('ID Покупателя')['Profit'].sum().sort_values(ascending=False)
# Out:
# ID Покупателя
# 7    17096.0
# 5    13043.0
# 8     1344.0
# 1        0.0
# Name: Profit, dtype: float64
