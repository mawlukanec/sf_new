# %%
import pandas as pd
pd.__version__

print(pd.__name__)
# Out:
# pandas

# %% [markdown]
# СОЗДАНИЕ SERIES

# %%
import pandas as pd
countries = pd.Series(
    data = ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    index = ['UK', 'CA', 'US', 'RU', 'UA', 'BY', 'KZ'],
    name = 'countries'
)

display(countries)
# Out:
# UK       Англия
# CA       Канада
# US          США
# RU       Россия
# UA      Украина
# BY     Беларусь
# KZ    Казахстан
# Name: countries, dtype: object
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 9
#       2 countries = pd.Series(
#       3     data = ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
#       4     index = ['UK', 'CA', 'US', 'RU', 'UA', 'BY', 'KZ'],
#       5     name = 'countries'
#       6 )
#       8 display(countries)
# ----> 9 display(countries.mean(axis=0, numeric_only= True))
#
# File c:\Users\pawel\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:6540, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6532 @doc(make_doc("mean", ndim=1))
#    6533 def mean(
#    6534     self,
#    (...)
#    6538     **kwargs,
#    6539 ):
# -> 6540     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File c:\Users\pawel\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:12417, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12410 def mean(
#   12411     self,
#   12412     axis: Axis | None = 0,
#    (...)
#   12415     **kwargs,
#   12416 ) -> Series | float:
# > 12417     return self._stat_function(
#   12418         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12419     )
#
# File c:\Users\pawel\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:12374, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12370 nv.validate_func(name, (), kwargs)
#   12372 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12374 return self._reduce(
#   12375     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12376 )
#
# File c:\Users\pawel\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:6444, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6442         kwd_name = "bool_only"
#    6443     # GH#47500 - change to TypeError to match other methods
# -> 6444     raise TypeError(
#    6445         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6446         "with non-numeric dtypes."
#    6447     )
#    6448 return op(delegate, skipna=skipna, **kwds)
#
# TypeError: Series.mean does not allow numeric_only=True with non-numeric dtypes.

# %%
import pandas as pd
countries = pd.Series({
    'UK': 'Англия',
    'CA': 'Канада',
    'US' : 'США',
    'RU': 'Россия',
    'UA': 'Украина',
    'BY': 'Беларусь',
    'KZ': 'Казахстан'},
    name = 'countries'
)
display(countries)
print(countries[[1,3, 5]])
# Out:
# UK       Англия
# CA       Канада
# US          США
# RU       Россия
# UA      Украина
# BY     Беларусь
# KZ    Казахстан
# Name: countries, dtype: object
# CA      Канада
# RU      Россия
# BY    Беларусь
# Name: countries, dtype: object
# C:\Users\pawel\AppData\Local\Temp\ipykernel_1496\3493936467.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(countries[[1,3, 5]])

# %% [markdown]
# В аптеку поступают партии лекарств. Их названия находятся в списке names, количество единиц товара находится в списке counts.
#
# Например:
#
# names = ['chlorhexidine', 'cyntomycin', 'afobazol'] counts = [15, 18, 7]
#
# Напишите функцию create_medications(names, counts), которая создает Series medications, индексами которой являются названия лекарств names, а значениями - их количество в поставке counts.
#
# А также напишите функцию get_percent(medications, name), которая возвращает долю количества товара с именем name от общего количества товаров в поставке в процентах.
#
# Примечание. Не забудьте ипортировать библиотеки.
#
# Пример:
#
# names=['chlorhexidine', 'cyntomycin', 'afobazol']
# counts=[15, 18, 7]
# medications = create_medications(names, counts)
#
# print(get_percent(medications, "chlorhexidine")) #37.5

# %%
import pandas as pd

#names=['chlorhexidine', 'cyntomycin', 'afobazol']
#counts=[15, 18, 7]

def create_medications(names, counts):
    medications = pd.Series(counts, names)
    return medications

def get_percent(medications, name):
    
    medications.loc[name]
    # sum_count = sum(medications[name])
    # print(medications.loc[name])
    # print(medications.iloc[1]+medications.iloc[2]+medications.iloc[0])
    return (medications.loc[name]/(medications.iloc[1]+medications.iloc[2]+medications.iloc[0]))*100
    
print(get_percent(name = 'cyntomycin', medications = create_medications(['chlorhexidine', 'cyntomycin', 'afobazol'],[26, 18, 7])))
# Out:
# 35.294117647058826

# %%
import pandas as pd
# countries_df.index = ['UK', 'CA', 'US', 'RU', 'UA', 'BY', 'KZ']
countries_df = pd.DataFrame({
    'country': ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    'population': [56.29, 38.05, 322.28, 146.24, 45.5, 9.5, 17.04],
    'area': [133396, 9984670, 9826630, 17125191, 603628, 207600, 2724902]
})

display(countries_df)
# countries_df.mean(axis=1, numeric_only=True)
countries_df.population
type(countries_df.population)
# Out:
#      country  population      area
# 0     Англия       56.29    133396
# 1     Канада       38.05   9984670
# 2        США      322.28   9826630
# 3     Россия      146.24  17125191
# 4    Украина       45.50    603628
# 5   Беларусь        9.50    207600
# 6  Казахстан       17.04   2724902
# pandas.core.series.Series

# %% [markdown]
# фильтрация и мн.др. из DataFrame

# %%
import pandas as pd
melb_data = pd.read_csv('d:/python/GUESS/РАБОЧАЯ/PANDAS/data/melb_data.csv', sep=',') # , encoding='windows 1251')
# Выведем первые пять строк нашей таблицы:
# display(melb_data.head())

# Следующий код выведет семь последних строк нашей таблицы:
# melb_data.tail(7)

#  кортеж с количеством строк и столбцов
# melb_data.shape
# melb_data.info()

melb_data['Car'] = melb_data['Car'].astype('int64')
melb_data['Bedroom'] = melb_data['Bedroom'].astype('int64')
melb_data['Bathroom'] = melb_data['Bathroom'].astype('int64')
melb_data['Propertycount'] = melb_data['Propertycount'].astype('int64')
melb_data['YearBuilt'] = melb_data['YearBuilt'].astype('int64')
# melb_data.info()

# # melb_data.describe().loc[:, ['Distance', 'BuildingArea' , 'Price']]
# temp_musik_xls = pd.read_excel('d:/python/GUESS/РАБОЧАЯ/PANDAS/data/musik(.xls).xls')
# #print(temp_musik_xls)
# #temp_musik_xls['ID кампании'] = temp_musik_xls['ID кампании'].astype('int64')
# temp_musik_xls.info()
# # g = ['Дата','Кампания','Запись','Потрачено, руб.','Выполненные заявки','Переходы по ссылкам']
# temp_musik_xls.describe()
# temp_musik_xls.describe().iloc[:, :]

#display(melb_data.mean(axis=0, numeric_only= True))

# melb_data.astype({'Distance': 'int', 'YearBuilt': 'int'}).dtypes
# melb_data.info()

# melb_data['Lattitude'].value_counts()
melb_data['Address'].value_counts()
melb_data['Coordinates'].value_counts()
melb_data.describe(include=['object'])

melb_data['Type'].value_counts(normalize=True)
# melb_data['Regionname'].value_counts(normalize=True)
# melb_data['CouncilArea'].value_counts()
#melb_data.iloc[:, [17]].count['NaN']

# melb_data['CouncilArea'].value_counts(normalize=True)
print(round(100*(abs(melb_data['BuildingArea'].median()- melb_data['BuildingArea'].mean())/melb_data['BuildingArea'].mean())))




mask = melb_data['Price'] > 2000000 
display(melb_data[mask].head())
# Out:
# 10
#     index       Suburb               Address  Rooms Type      Price Method  \
# 80     80  Albert Park  112 Beaconsfield Pde      3    h  2850000.0     PI
# 85     85  Albert Park     104 Richardson St      4    h  2300000.0      S
# 88     88  Albert Park        29 Faussett St      2    h  2120000.0      S
# 92     92  Albert Park           2 Dundas Pl      3    h  2615000.0      S
# 93     93  Albert Park          23 Finlay St      5    h  2100000.0      S
#
#      SellerG        Date  Distance  ...  Car  Landsize  BuildingArea  \
# 80    Buxton   4/03/2017       3.3  ...    0     211.0         198.0
# 85  Marshall   7/05/2016       3.3  ...    1     153.0         180.0
# 88      Greg  10/09/2016       3.3  ...    1     199.0         107.0
# 92    Cayzer  10/12/2016       3.3  ...    1     177.0         181.0
# 93      Greg  10/12/2016       3.3  ...    1     237.0         126.0
#
#     YearBuilt   CouncilArea  Lattitude  Longtitude             Regionname  \
# 80       1890  Port Phillip   -37.8481    144.9499  Southern Metropolitan
# 85       1880  Port Phillip   -37.8447    144.9523  Southern Metropolitan
# 88       1900  Port Phillip   -37.8422    144.9554  Southern Metropolitan
# 92       1880  Port Phillip   -37.8415    144.9585  Southern Metropolitan
# 93       1970  Port Phillip   -37.8436    144.9557  Southern Metropolitan
#
#     Propertycount         Coordinates
# 80           3280  -37.8481, 144.9499
# 85           3280  -37.8447, 144.9523
# 88           3280  -37.8422, 144.9554
# 92           3280  -37.8415, 144.9585
# 93           3280  -37.8436, 144.9557
#
# [5 rows x 23 columns]
